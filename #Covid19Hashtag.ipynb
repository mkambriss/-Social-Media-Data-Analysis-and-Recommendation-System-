# %%
pip install -U setuptools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install auto-py-to-exe
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
pip install --upgrade pip setuptools wheel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import twint

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Instantiate and configure the twint-object
c = twint.Config()
c.Store_object = True
c.Pandas =True
c.Search = "lang:en #covid19"
c.Limit = 15
c.Lang = 'en'

# %%
twint.run.Search(c)
# Out:
# 1539641909643198468 2022-06-22 19:10:11 +0300 <NatureCVR> If you don't have access to @NatureCVR, please talk to your librarian. In the meantime, we are making a few selected articles  #freetoread for a month. Read a fantastic Review article by @GiaccaMauro  &amp;Ajay Shah #COVID19 #cardiovascular #Cardiotwitter  https://t.co/1vQop8Tvyh
# 1539641888763953157 2022-06-22 19:10:06 +0300 <MottMacDonald> Listen to our global practice lead Clare Wildfire and Madeleine Rawlins join the @SmartCitiesW podcast to discuss progressing the narrative on #UrbanClimateAction and the potential for a green recovery from the #Covid19 pandemic. 👇   https://t.co/yZdO9gRfUf
# ...

# %%
Tweets_df = twint.storage.panda.Tweets_df

# %%
# Quick check
kk=twint.storage.panda.Tweets_df.head(15)
kk
# Out:
#                      id      conversation_id    created_at  \
# 0   1539641909643198468  1539641909643198468  1.655914e+12
# 1   1539641888763953157  1539641888763953157  1.655914e+12
# 2   1539641876608757760  1539641876608757760  1.655914e+12
# 3   1539641864269271040  1539641864269271040  1.655914e+12
# 4   1539641847558991872  1538945510609911813  1.655914e+12
# 5   1539641817683136515  1539641817683136515  1.655914e+12
# 6   1539641777518325760  1539641777518325760  1.655914e+12
# 7   1539641767301201922  1539641767301201922  1.655914e+12
# 8   1539641710879416320  1539641710879416320  1.655914e+12
# 9   1539641706148073472  1539641706148073472  1.655914e+12
# 10  1539641695645859840  1539641695645859840  1.655914e+12
# 11  1539641648526811137  1539640975513239553  1.655914e+12
# 12  1539641559729475585  1539607818659037184  1.655914e+12
# 13  1539641514691035136  1539641512715505664  1.655914e+12
# 14  1539641512715505664  1539641512715505664  1.655914e+12
#
# ...

# %%
#save as csv
kk.to_csv('rawdata2.csv', encoding='utf-8', index=False)

# %%
# Cleanup
tweets = twint.storage.panda.Tweets_df.drop_duplicates(subset=['id'])
